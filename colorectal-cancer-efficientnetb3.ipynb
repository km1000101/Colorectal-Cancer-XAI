# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/colorectal-histology-mnist/hmnist_64_64_L.csv
# /kaggle/input/colorectal-histology-mnist/hmnist_8_8_RGB.csv
# /kaggle/input/colorectal-histology-mnist/hmnist_28_28_RGB.csv
# /kaggle/input/colorectal-histology-mnist/hmnist_8_8_L.csv
# /kaggle/input/colorectal-histology-mnist/hmnist_28_28_L.csv
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-03_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-01_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-05_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-08_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-06_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-02-APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-04_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-10_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-07_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-09_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-03_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-01_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-05_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-08_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-06_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-02-APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-04_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-10_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-07_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_larger_images_10/Kather_texture_2016_larger_images_10/CRC-Prim-HE-09_APPLICATION.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/B7BA_CRC-Prim-HE-09_006.tif_Row_151_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/ADE7_CRC-Prim-HE-09_007.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11213_CRC-Prim-HE-01_007.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D9A_CRC-Prim-HE-05_003.tif_Row_151_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/68D4_CRC-Prim-HE-05_004.tif_Row_301_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A04E_CRC-Prim-HE-05_004.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5097_CRC-Prim-HE-02.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15734_CRC-Prim-HE-02_012.tif_Row_601_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E6A1_CRC-Prim-HE-01_038.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A43E_CRC-Prim-HE-01_004.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F19C_CRC-Prim-HE-02.tif_Row_751_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/127BF_CRC-Prim-HE-01_004.tif_Row_1051_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/115EF_CRC-Prim-HE-05_003.tif_Row_451_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/CAA7_CRC-Prim-HE-01_004.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F55A_CRC-Prim-HE-01_013.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/26D6_CRC-Prim-HE-05_003.tif_Row_151_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/B085_CRC-Prim-HE-05_010.tif_Row_601_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1BFE_CRC-Prim-HE-05_004.tif_Row_601_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/C4E0_CRC-Prim-HE-05_004.tif_Row_601_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1FD7_CRC-Prim-HE-04_031.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9FF6_CRC-Prim-HE-01.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/55CA_CRC-Prim-HE-01_006b.tif_Row_151_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11EC6_CRC-Prim-HE-05_003.tif_Row_151_Col_1951.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5945_CRC-Prim-HE-10c.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9DD4_CRC-Prim-HE-02.tif_Row_601_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15F60_CRC-Prim-HE-01_005.tif_Row_301_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1819_CRC-Prim-HE-05_004.tif_Row_151_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1709D_CRC-Prim-HE-02.tif_Row_451_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E403_CRC-Prim-HE-01.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/166F_CRC-Prim-HE-02_002.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13DA_CRC-Prim-HE-09_020.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1198_CRC-Prim-HE-01_004.tif_Row_1_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13CC9_CRC-Prim-HE-05_023.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10292_CRC-Prim-HE-02_016.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10B3B_CRC-Prim-HE-05_028.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6FCF_CRC-Prim-HE-05_022.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13F45_CRC-Prim-HE-01_006b.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7BD2_CRC-Prim-HE-05_004.tif_Row_1_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/92A0_CRC-Prim-HE-09_013.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/121E3_CRC-Prim-HE-09_006.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/AFA3_CRC-Prim-HE-02_copy.tif_Row_151_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/4B75_CRC-Prim-HE-01_038.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/73D4_CRC-Prim-HE-09_008.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13EF0_CRC-Prim-HE-05_004.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/119A9_CRC-Prim-HE-07_002.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3C8A_CRC-Prim-HE-06_036.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/4D2F_CRC-Prim-HE-02.tif_Row_901_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/4A8E_CRC-Prim-HE-06.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16AF0_CRC-Prim-HE-05_003.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/ECA5_CRC-Prim-HE-01_004.tif_Row_901_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12F3E_CRC-Prim-HE-01_004.tif_Row_151_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/18464_CRC-Prim-HE-01_005.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/472E_CRC-Prim-HE-09_019.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/34_CRC-Prim-HE-10c.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6598_CRC-Prim-HE-01_004.tif_Row_901_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15556_CRC-Prim-HE-05_003.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12573_CRC-Prim-HE-01_005.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F904_CRC-Prim-HE-05_003.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3DF8_CRC-Prim-HE-08_011.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/CC37_CRC-Prim-HE-05_010.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/17E2B_CRC-Prim-HE-01_006b.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3CF5_CRC-Prim-HE-05_003.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F864_CRC-Prim-HE-10_011.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/FCB2_CRC-Prim-HE-02_012.tif_Row_751_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/114CC_CRC-Prim-HE-04_031.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13262_CRC-Prim-HE-01_004.tif_Row_601_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6BA1_CRC-Prim-HE-04_031.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/289A_CRC-Prim-HE-01b.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D6C1_CRC-Prim-HE-02.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11276_CRC-Prim-HE-05_003.tif_Row_301_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15858_CRC-Prim-HE-01_004.tif_Row_151_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6AE0_CRC-Prim-HE-01_007.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5971_CRC-Prim-HE-03_032.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/18512_CRC-Prim-HE-01_004.tif_Row_451_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/153FC_CRC-Prim-HE-01_004.tif_Row_1_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/17AC7_CRC-Prim-HE-09_006.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/113AA_CRC-Prim-HE-02_001b.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/113D_CRC-Prim-HE-09_021.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/14EB0_CRC-Prim-HE-05_023.tif_Row_451_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/172EB_CRC-Prim-HE-05_003.tif_Row_151_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9D36_CRC-Prim-HE-09_020.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D6C9_CRC-Prim-HE-02_002.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/2A0B_CRC-Prim-HE-01_004.tif_Row_151_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5239_CRC-Prim-HE-05_003.tif_Row_151_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D0E9_CRC-Prim-HE-05_004.tif_Row_451_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15019_CRC-Prim-HE-02_copy.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7C4E_CRC-Prim-HE-05_023.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9C0C_CRC-Prim-HE-01_001.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/114D_CRC-Prim-HE-05_003.tif_Row_451_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12D8E_CRC-Prim-HE-09_008.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E8_CRC-Prim-HE-09_006.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15668_CRC-Prim-HE-01_004.tif_Row_601_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/72A4_CRC-Prim-HE-01_004.tif_Row_751_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/176E8_CRC-Prim-HE-05_003.tif_Row_301_Col_1951.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1017A_CRC-Prim-HE-05_022.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9A6C_CRC-Prim-HE-09_008.tif_Row_1_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/B44C_CRC-Prim-HE-02_001b.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E266_CRC-Prim-HE-01_004.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6909_CRC-Prim-HE-02_002b.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F3CF_CRC-Prim-HE-05_003.tif_Row_1_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1455C_CRC-Prim-HE-05_003.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/584E_CRC-Prim-HE-05_003.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/168E4_CRC-Prim-HE-05_004.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/2728_CRC-Prim-HE-02.tif_Row_1_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5EA0_CRC-Prim-HE-09_005.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/DF8_CRC-Prim-HE-01_004b.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D91_CRC-Prim-HE-05_003.tif_Row_151_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3FBD_CRC-Prim-HE-05_003.tif_Row_301_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/114AD_CRC-Prim-HE-02_002b.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A138_CRC-Prim-HE-05_003.tif_Row_451_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1115E_CRC-Prim-HE-01_006b.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/131BF_CRC-Prim-HE-09_019.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/175DF_CRC-Prim-HE-01_001b.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1F89_CRC-Prim-HE-05_010.tif_Row_1201_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10B0B_CRC-Prim-HE-01_013.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/17092_CRC-Prim-HE-01_004.tif_Row_601_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11510_CRC-Prim-HE-02_002.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E1F7_CRC-Prim-HE-09_006.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9715_CRC-Prim-HE-01.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/130C_CRC-Prim-HE-01_004.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/407E_CRC-Prim-HE-01_006b.tif_Row_301_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1434D_CRC-Prim-HE-05_022.tif_Row_601_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/860A_CRC-Prim-HE-05_004.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/131C2_CRC-Prim-HE-05_010.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16815_CRC-Prim-HE-01_004.tif_Row_751_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13BD0_CRC-Prim-HE-01_005.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A72D_CRC-Prim-HE-01_004.tif_Row_751_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/96C0_CRC-Prim-HE-05_010.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/BF6D_CRC-Prim-HE-01_007.tif_Row_151_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/18415_CRC-Prim-HE-01_004.tif_Row_901_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16F1B_CRC-Prim-HE-05_010.tif_Row_151_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15865_CRC-Prim-HE-05_010.tif_Row_1351_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E115_CRC-Prim-HE-01b.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/39B8_CRC-Prim-HE-01_005.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15CF5_CRC-Prim-HE-05_023.tif_Row_151_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10A01_CRC-Prim-HE-01_004b.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16C7C_CRC-Prim-HE-01_038.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/125B5_CRC-Prim-HE-01_006b.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/C734_CRC-Prim-HE-09_008.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/18D7_CRC-Prim-HE-09_005.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/DF8_CRC-Prim-HE-09_005.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16C25_CRC-Prim-HE-01_004.tif_Row_901_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/AFD6_CRC-Prim-HE-02_012.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15209_CRC-Prim-HE-05_010.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7D2E_CRC-Prim-HE-05_022.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13778_CRC-Prim-HE-09_013.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A263_CRC-Prim-HE-04_031.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9E06_CRC-Prim-HE-01_005.tif_Row_451_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10527_CRC-Prim-HE-02_001b.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A1EA_CRC-Prim-HE-09_006.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12CD8_CRC-Prim-HE-01_002.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/574E_CRC-Prim-HE-05_022.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12ECA_CRC-Prim-HE-02.tif_Row_451_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/14CD3_CRC-Prim-HE-01_006b.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/161BD_CRC-Prim-HE-05_023.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13AFC_CRC-Prim-HE-02_002b.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/EA4E_CRC-Prim-HE-09_013.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10EF_CRC-Prim-HE-08_011.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F0A2_CRC-Prim-HE-08_011.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/62C1_CRC-Prim-HE-09_019.tif_Row_601_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/2EA4_CRC-Prim-HE-02_002b.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/832_CRC-Prim-HE-02_001.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6761_CRC-Prim-HE-05_003.tif_Row_301_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12497_CRC-Prim-HE-01_005.tif_Row_151_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5257_CRC-Prim-HE-01_005.tif_Row_301_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7A6_CRC-Prim-HE-05_022.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/789D_CRC-Prim-HE-01_004.tif_Row_1051_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/2E91_CRC-Prim-HE-05_023.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D0BB_CRC-Prim-HE-01_004.tif_Row_751_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13785_CRC-Prim-HE-09_007.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1650D_CRC-Prim-HE-01_001.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15213_CRC-Prim-HE-05_003.tif_Row_451_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1632E_CRC-Prim-HE-01_004.tif_Row_1051_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/FBBC_CRC-Prim-HE-02.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A02F_CRC-Prim-HE-01_002.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/770C_CRC-Prim-HE-05_003.tif_Row_451_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/E4FF_CRC-Prim-HE-01.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/16592_CRC-Prim-HE-02.tif_Row_751_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15692_CRC-Prim-HE-01_013.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9390_CRC-Prim-HE-02_002.tif_Row_751_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/811D_CRC-Prim-HE-09_006.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/2CE1_CRC-Prim-HE-01b.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1776C_CRC-Prim-HE-06.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D33A_CRC-Prim-HE-05_010.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/ED43_CRC-Prim-HE-01_006b.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12402_CRC-Prim-HE-01_029.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/51B0_CRC-Prim-HE-05_010.tif_Row_601_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6879_CRC-Prim-HE-05_003.tif_Row_451_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/66C5_CRC-Prim-HE-02_copy.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/507_CRC-Prim-HE-01_004.tif_Row_301_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3F4E_CRC-Prim-HE-01_006b.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/FC2B_CRC-Prim-HE-05_028.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/9C1E_CRC-Prim-HE-09_005.tif_Row_601_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13AAC_CRC-Prim-HE-10c.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/8816_CRC-Prim-HE-02_002b.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/110A9_CRC-Prim-HE-02.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/F3A3_CRC-Prim-HE-01_001.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/17BFA_CRC-Prim-HE-09_013.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D6FE_CRC-Prim-HE-01_006.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/24BD_CRC-Prim-HE-05_004.tif_Row_601_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13DD5_CRC-Prim-HE-02_012.tif_Row_601_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3BA8_CRC-Prim-HE-01_006.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7E0F_CRC-Prim-HE-01_004.tif_Row_751_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/C23E_CRC-Prim-HE-01_004.tif_Row_301_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/124E8_CRC-Prim-HE-05_003.tif_Row_1_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/13E35_CRC-Prim-HE-01_004.tif_Row_901_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A523_CRC-Prim-HE-01_004.tif_Row_751_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6F23_CRC-Prim-HE-01b.tif_Row_601_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15548_CRC-Prim-HE-05_003.tif_Row_451_Col_1951.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/4D68_CRC-Prim-HE-02.tif_Row_901_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/176D9_CRC-Prim-HE-01b.tif_Row_451_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/49C0_CRC-Prim-HE-02.tif_Row_451_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/31FA_CRC-Prim-HE-02.tif_Row_901_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7993_CRC-Prim-HE-01_002.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/134DA_CRC-Prim-HE-01_029.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/15C76_CRC-Prim-HE-01_005.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/58BD_CRC-Prim-HE-08_011.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D26A_CRC-Prim-HE-01_004.tif_Row_601_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/D948_CRC-Prim-HE-09_006.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1030C_CRC-Prim-HE-05_010.tif_Row_1051_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12B06_CRC-Prim-HE-01_029.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7CAA_CRC-Prim-HE-10c.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5F31_CRC-Prim-HE-02_012.tif_Row_751_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A8CF_CRC-Prim-HE-09_006.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1985_CRC-Prim-HE-02.tif_Row_601_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/39FB_CRC-Prim-HE-05_003.tif_Row_1_Col_1801.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/66FC_CRC-Prim-HE-05_010.tif_Row_901_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/587_CRC-Prim-HE-01_001.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/183D2_CRC-Prim-HE-05_003.tif_Row_1_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1331C_CRC-Prim-HE-01_004.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/46F7_CRC-Prim-HE-05_010.tif_Row_1051_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10B84_CRC-Prim-HE-04_031.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1CF0_CRC-Prim-HE-04_031.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/7B7_CRC-Prim-HE-05_003.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/14DB0_CRC-Prim-HE-01_001.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11E80_CRC-Prim-HE-01_004.tif_Row_1051_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/CDE7_CRC-Prim-HE-05_004.tif_Row_151_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/140C0_CRC-Prim-HE-05_003.tif_Row_451_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/5266_CRC-Prim-HE-02_copy.tif_Row_151_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/A290_CRC-Prim-HE-04_031.tif_Row_1_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/119C5_CRC-Prim-HE-08_011.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/104E0_CRC-Prim-HE-02.tif_Row_1051_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/14EF6_CRC-Prim-HE-04_031.tif_Row_301_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/17C5B_CRC-Prim-HE-02_012.tif_Row_451_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/111EF_CRC-Prim-HE-02.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/571C_CRC-Prim-HE-05_004.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/3031_CRC-Prim-HE-01_029.tif_Row_151_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/11221_CRC-Prim-HE-02_002b.tif_Row_301_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/6CCE_CRC-Prim-HE-01_005.tif_Row_1_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/1834_CRC-Prim-HE-02_002b.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/10F16_CRC-Prim-HE-09_013.tif_Row_301_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/63F9_CRC-Prim-HE-05_023.tif_Row_1_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/B7F8_CRC-Prim-HE-06.tif_Row_301_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/540E_CRC-Prim-HE-01_004.tif_Row_451_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/12598_CRC-Prim-HE-05_004.tif_Row_301_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/C1A8_CRC-Prim-HE-01_005.tif_Row_1_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/DE83_CRC-Prim-HE-01_006b.tif_Row_1_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/14A_CRC-Prim-HE-01_001.tif_Row_151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/8D82_CRC-Prim-HE-01_005.tif_Row_301_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/04_LYMPHO/63EA_CRC-Prim-HE-05_023.tif_Row_451_Col_151.tif
# ...
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599420186946-7b6fb4e297f0 (3).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1514908135297-d8b4af35ee80.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1553272725-086100aecf5e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634990521982-567167cd6955.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636742146345-cab95273c11a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1571215682742-561893604b40.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635488638958-5dd6137f7995.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1519778119555-47f8a0929968.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1594118313797-0fe882874416.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1577268173819-d36a3378f8d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1611728337177-89dfbbdc7a3a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1552679978-f908a45fb2d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635994449857-0ead6ac27eb9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636361479581-5ab1a7a72beb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1545063914-a1a6ec821c88.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635924010446-c2a9851859af.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635435581456-18823ecff579.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1551106652-a5bcf4b29ab6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634654422250-9f4526b8453c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634662520758-4d22c890b486.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636541745435-fdfeb585e603.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638136166572-77e9b849cee9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637258977274-d5aeac876d6c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638148979208-32bab8e7b449.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1632664280478-6755fd5dafc1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634658602584-fbf13d8a5def.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635206936639-a81691418fbf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1579885487896-abc1a9ebb77b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636015348041-cea51783d2ec.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635286721033-e11cf9e632c4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633157953349-75c66213ca2f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635273439931-07f24478bec5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638088652284-bd605e73d56e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635993522806-a9998e360804.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1626303047287-5d712b21accc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635512845522-9ac2bf78efae.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635931907849-f2109d3aecf3 (1).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639027225628-11003e28fb97.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1608475381161-c2a19bdf165d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638130419943-1242ff0300bf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635979122332-93e6d4c60c23.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638176096256-47c8b2a03d65.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637354563042-9a1d26500ff5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627930324332-c0c3bd5ccb20.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599581148873-b1df350d667f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635089997590-64c4f086642e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1524639099061-f8beec2b7538.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636244411431-e4ac0ce7b52d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637703586699-273e18448fb4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638041864014-13a7e7862d4b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637406303130-cf17cf5358da.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1621849400072-f554417f7051.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635860219388-679615753997.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639003978704-d589e8133b74.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635924941939-2b58521c61fa.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637734433731-621aca1c8cb6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1622120573848-718f49c359d5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635262543956-948245c215d3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635950533753-39e59a5a1d74.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635768882868-7ba5f453222d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636145411033-41bb1b898d5c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637311859464-5021233b7da5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635737588547-a8d97c2fb531.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638975983437-2f5fea7540da.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637677121980-6f39c0b61500.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635438731506-5dedcd48314c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1554570731-63bcddda4dcd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634470943030-8ceaff41a0ea.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638939674935-02c70476ea20.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638047160224-5d692d9dc764.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638082676826-b3cde493af3b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1569174237922-5689ad487104.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1631698637575-f9445d7faa7d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637093500098-078c033893c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639034741604-f85d9d1a7c6f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638108715699-eb983bcfa53e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1557517395-f8dff7f191e7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635959565667-aeb00a4297ba.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1552205526-7ad7c9aa94c7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1622927101721-c9315c019a25.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1632175169571-2b12d9709fee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635718213398-3bcd1a9ffcb7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633706351407-49fc9a63ff9e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638115684794-0d6b902057d9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636307778279-df1879e0de97.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637758180067-71d95d566a9e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633114127188-99b4dd741180.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1572502006585-8d45f2d2c72b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1607546916525-0d0498c5f5d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638978443174-246d17bfb608.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1583139937725-8ccafdb2db1b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1485550409059-9afb054cada4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638991591017-4c6689266bec.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1631884284118-a53ef8540111.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636132694371-9b92d0b6e928.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636127321340-4380c87936f8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1603374431352-8a072a395d6e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113093730-47449a1a9c6e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1536329583941-14287ec6fc4e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638122661212-0253f46bb978.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635951994645-a051b055cd92.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636038236932-42d8ce006707.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638828616477-fe4f7c8c4eed.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1550651672-e5f43068b885.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633354585554-0f022d8a91dc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639008941093-58210662b279.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1571816119607-57e48af1caa9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633884187493-7f2012547051.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1629067637999-d95d9182ab02.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1628193826226-a7c781daa6c1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635354454616-bbbe093f3165.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638181017631-681188db55ee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636136569435-d8221eb684bb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636192677130-83a4cbd0f7d3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637740000367-e95c17dddcc4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627844718641-f3bda7d6050b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637094090928-cb95001ef49f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635406726707-a25a0dbc2e14.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636151191432-f2f290a57fd4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636866764019-e230ab5c9d08.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1516747773440-e114ee0d3c07.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636126176840-c61d03604424.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636036110946-d8c905470b7f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638037143715-eac0b33d1003.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635593701844-c54cec733034.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1578663300016-461177ffd732.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1588272947905-24bec36c176d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636071657754-5b0a8760c4b9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637637498218-44ad7c174ec5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1576021182211-9ea8dced3690.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1614191697800-ff83bd175cee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637410130290-a905c3f910e9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1593642702749-b7d2a804fbcf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627269817325-8da9fc719c29.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637090106163-0288a4fb33d5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635353779138-0fddba218a30.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1632908112019-0e27ef1e70d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638062414145-e0dd0824d0b8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635345825088-98068082ca5e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635941607659-ab0159f89611.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637260228557-a1a7810b991f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637756520113-e42adcfc83ab.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635259351767-8317d3ff988e.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms, models
import torchvision.models as models
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import seaborn as sns
from PIL import Image
import os
from collections import Counter
import warnings
import gc
from tqdm.auto import tqdm
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

class ColorectalCancerDataset(Dataset):
    def __init__(self, root_dir, transform=None, unknown_dir=None, max_unknown=None):
        """
        root_dir: directory containing the 8 colorectal class folders.
        unknown_dir: directory containing random/unsupervised images (Unsplash).
        All images in unknown_dir are labeled as 'UNKNOWN'.
        """
        self.root_dir = root_dir
        self.unknown_dir = unknown_dir
        self.transform = transform
        
        # 8 colorectal classes + 1 UNKNOWN
        self.classes = [
            '01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO',
            '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY',
            'UNKNOWN'
        ]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        
        self.samples = []
        self.class_counts = Counter()
        
        # Original 8 classes from colorectal dataset
        for class_name in self.classes:
            if class_name == 'UNKNOWN':
                continue
            class_path = os.path.join(root_dir, class_name)
            if os.path.exists(class_path):
                class_images = []
                for img_name in os.listdir(class_path):
                    if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.tif')):
                        img_path = os.path.join(class_path, img_name)
                        class_images.append((img_path, self.class_to_idx[class_name]))
                
                self.samples.extend(class_images)
                self.class_counts[class_name] = len(class_images)
        
        # UNKNOWN class from Unsplash random images folder (flat directory)
        if self.unknown_dir is not None and os.path.exists(self.unknown_dir):
            unknown_images = []
            for img_name in os.listdir(self.unknown_dir):
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.tif')):
                    img_path = os.path.join(self.unknown_dir, img_name)
                    unknown_images.append((img_path, self.class_to_idx['UNKNOWN']))
            
            # Optionally cap number of unknowns so they don't dominate
            if max_unknown is not None:
                unknown_images = unknown_images[:max_unknown]
            
            self.samples.extend(unknown_images)
            self.class_counts['UNKNOWN'] = len(unknown_images)
        
        print("Class counts:", self.class_counts)
        print("Total samples:", len(self.samples))
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        try:
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            return image, label
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a dummy image in case of error
            dummy_image = Image.new('RGB', (224, 224), color='black')
            if self.transform:
                dummy_image = self.transform(dummy_image)
            return dummy_image, label

class EfficientNetB3Classifier(nn.Module):
    def __init__(self, num_classes=9, dropout_rate=0.5):
        super(EfficientNetB3Classifier, self).__init__()
        
        # Load pretrained EfficientNet-B3 with ImageNet weights [web:71][web:72]
        try:
            self.backbone = models.efficientnet_b3(weights="IMAGENET1K_V1")
            print("EfficientNet-B3 with IMAGENET1K_V1 weights loaded successfully")
        except Exception as e:
            print("Error loading EfficientNet-B3 pretrained weights:", e)
            raise
        
        # Freeze early layers for stable training
        for param in list(self.backbone.parameters())[:-30]:
            param.requires_grad = False
        
        # Replace classifier head (EfficientNet-B3 uses a Sequential 'classifier' module) [web:75]
        in_features = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Sequential(
            nn.Dropout(p=dropout_rate),
            nn.Linear(in_features, 512),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),
            nn.Dropout(p=dropout_rate * 0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(256),
            nn.Dropout(p=dropout_rate * 0.3),
            nn.Linear(256, num_classes)
        )
    
    def forward(self, x):
        return self.backbone(x)

class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.001, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta
        self.restore_best_weights = restore_best_weights
        self.best_loss = None
        self.counter = 0
        self.best_weights = None
        
    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(model)
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.save_checkpoint(model)
        else:
            self.counter += 1
            
        if self.counter >= self.patience:
            if self.restore_best_weights and self.best_weights is not None:
                model.load_state_dict(self.best_weights)
            return True
        return False
    
    def save_checkpoint(self, model):
        self.best_weights = {k: v.clone() for k, v in model.state_dict().items()}

def get_transforms():
    train_transform = transforms.Compose([
        transforms.Resize((224, 224)),  
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
        transforms.RandomApply([transforms.GaussianBlur(kernel_size=3)], p=0.2),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    val_test_transform = transforms.Compose([
        transforms.Resize((224, 224)), 
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    return train_transform, val_test_transform

def create_data_loaders(dataset_dir, batch_size=32, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15,
                        unknown_dir=None, max_unknown=None):
    """
    Create train, validation, and test data loaders with 70-15-15 split
    including UNSPLASH random images as UNKNOWN class.
    """
    print("Creating data loaders with 70-15-15 split...")
    
    # Get transforms
    train_transform, val_test_transform = get_transforms()
    
    # Load dataset once with no transform
    full_dataset = ColorectalCancerDataset(
        dataset_dir,
        transform=None,
        unknown_dir=unknown_dir,
        max_unknown=max_unknown
    )
    
    # Calculate split sizes
    total_size = len(full_dataset)
    train_size = int(train_ratio * total_size)
    val_size = int(val_ratio * total_size)
    test_size = total_size - train_size - val_size
    
    # Random split
    generator = torch.Generator().manual_seed(42)
    train_dataset, val_dataset, test_dataset = random_split(
        full_dataset, [train_size, val_size, test_size], generator=generator
    )
    
    # Assign transforms to each split
    train_dataset.dataset.transform = train_transform
    val_dataset.dataset.transform = val_test_transform
    test_dataset.dataset.transform = val_test_transform
    
    # Create data loaders 
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, 
        num_workers=0, pin_memory=True, drop_last=True
    )
    val_loader = DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, 
        num_workers=0, pin_memory=True
    )
    test_loader = DataLoader(
        test_dataset, batch_size=batch_size, shuffle=False, 
        num_workers=0, pin_memory=True
    )
    
    print(f"Train size: {len(train_dataset)}, Val size: {len(val_dataset)}, Test size: {len(test_dataset)}")
    return train_loader, val_loader, test_loader, full_dataset.classes

def train_model(model, train_loader, val_loader, device, num_epochs=40):
    # Loss function with label smoothing
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    
    # Optimizer - AdamW with weight decay
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    
    # Learning rate scheduler
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)
    
    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.001)
    
    # History tracking
    history = {
        'train_loss': [], 'train_acc': [],
        'val_loss': [], 'val_acc': []
    }
    
    best_val_acc = 0.0
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0
        
        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')
        for batch_idx, (data, target) in enumerate(train_pbar):
            data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            train_total += target.size(0)
            train_correct += (predicted == target).sum().item()
            
            # Update progress bar
            train_pbar.set_postfix({
                'Loss': f'{loss.item():.4f}',
                'Acc': f'{100.*train_correct/train_total:.2f}%'
            })
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]')
            for data, target in val_pbar:
                data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
                output = model(data)
                loss = criterion(output, target)
                
                val_loss += loss.item()
                _, predicted = torch.max(output.data, 1)
                val_total += target.size(0)
                val_correct += (predicted == target).sum().item()
                
                val_pbar.set_postfix({
                    'Loss': f'{loss.item():.4f}',
                    'Acc': f'{100.*val_correct/val_total:.2f}%'
                })
        
        # Calculate metrics
        train_loss_avg = train_loss / len(train_loader)
        train_acc = 100. * train_correct / train_total
        val_loss_avg = val_loss / len(val_loader)
        val_acc = 100. * val_correct / val_total
        
        # Update history
        history['train_loss'].append(train_loss_avg)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss_avg)
        history['val_acc'].append(val_acc)
        
        print(f'\n Epoch {epoch+1}/{num_epochs} Results:')
        print(f'   Train Loss: {train_loss_avg:.4f}, Train Acc: {train_acc:.2f}%')
        print(f'   Val Loss: {val_loss_avg:.4f}, Val Acc: {val_acc:.2f}%')
        
        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'best_colorectal_model.pth')
            print(f'    New best model saved! Val Acc: {best_val_acc:.2f}%')
        
        print('-' * 70)
        
        # Learning rate scheduling
        scheduler.step()
        
        # Early stopping
        if early_stopping(val_loss_avg, model):
            print(f' Early stopping triggered after epoch {epoch+1}')
            break
        
        # Memory cleanup
        if epoch % 10 == 0:
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
    
    return history, best_val_acc

def evaluate_model(model, test_loader, device, class_names):
    model.eval()
    all_preds = []
    all_targets = []
    all_probs = []
    
    with torch.no_grad():
        test_pbar = tqdm(test_loader, desc='Evaluating')
        for data, target in test_pbar:
            data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
            output = model(data)
            probs = torch.softmax(output, dim=1)
            _, predicted = torch.max(output, 1)
            
            all_preds.extend(predicted.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())
    
    return np.array(all_preds), np.array(all_targets), np.array(all_probs)

def plot_training_history(history):
    plt.style.use('default')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Plot training & validation accuracy
    epochs = range(1, len(history['train_acc']) + 1)
    ax1.plot(epochs, history['train_acc'], 'b-', label='Training Accuracy', linewidth=2)
    ax1.plot(epochs, history['val_acc'], 'r-', label='Validation Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Accuracy (%)', fontsize=12)
    ax1.legend(fontsize=10)
    ax1.grid(True, alpha=0.3)
    ax1.set_ylim([0, 100])
    
    # Plot training & validation loss
    ax2.plot(epochs, history['train_loss'], 'b-', label='Training Loss', linewidth=2)
    ax2.plot(epochs, history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
    ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Loss', fontsize=12)
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Number of Samples'})
    plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    return cm

def plot_roc_curves(y_true, y_probs, class_names):
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    
    plt.figure(figsize=(14, 10))
    colors = plt.cm.Set3(np.linspace(0, 1, n_classes))
    
    mean_auc = 0
    for i, (class_name, color) in enumerate(zip(class_names, colors)):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
        roc_auc = auc(fpr, tpr)
        mean_auc += roc_auc
        plt.plot(fpr, tpr, color=color, lw=3, 
                label=f'{class_name} (AUC = {roc_auc:.3f})')
    
    mean_auc /= n_classes
    plt.plot([0, 1], [0, 1], 'k--', lw=2, alpha=0.8, label='Random Classifier (AUC = 0.500)')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title(f'ROC Curves - Multi-class Classification\nMean AUC = {mean_auc:.3f}', 
              fontsize=14, fontweight='bold')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    return mean_auc

def main():
    # Path for colorectal histology MNIST dataset
    DATASET_DIR = '/kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000'
    
    # Path for Unsplash random images dataset (flat folder with images)
    UNSPLASH_DIR = '/kaggle/input/unsplash-random-images-collection/unsplash-images-collection'
    
    BATCH_SIZE = 32  
    NUM_EPOCHS = 40  
    
    print(" Starting Colorectal Cancer Classification with EfficientNet-B3 + UNKNOWN class")
    print("=" * 60)
    
    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f" Using device: {device}")
    
    # Create data loaders with 70-15-15 split
    print("\n" + "=" * 60)
    train_loader, val_loader, test_loader, class_names = create_data_loaders(
        DATASET_DIR,
        BATCH_SIZE,
        train_ratio=0.7,
        val_ratio=0.15,
        test_ratio=0.15,
        unknown_dir=UNSPLASH_DIR,
        max_unknown=500  # adjust or remove cap as you like
    )
    
    print(f"\n Dataset Information:")
    print(f"   Classes: {class_names}")
    
    # Create model (num_classes inferred from class_names length)
    print(f"\n Building EfficientNet-B3 model...")
    model = EfficientNetB3Classifier(num_classes=len(class_names), dropout_rate=0.5)
    model.to(device)
    
    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Total params: {total_params}, Trainable params: {trainable_params}")
    
    # Train model
    print("\n" + "=" * 60)
    print(" Starting training...")
    history, best_val_acc = train_model(model, train_loader, val_loader, device, NUM_EPOCHS)
    
    # Load best model for evaluation
    model.load_state_dict(torch.load('best_colorectal_model.pth'))
    print(f"\n Best validation accuracy achieved: {best_val_acc:.2f}%")
    
    # Plot training history
    print("\n Plotting training history...")
    plot_training_history(history)
    
    # Evaluate on test set
    print("\n" + "=" * 60)
    print(" Evaluating on test set...")
    y_pred, y_true, y_probs = evaluate_model(model, test_loader, device, class_names)
    
    # Calculate final test accuracy
    test_accuracy = (y_pred == y_true).mean() * 100
    print(f"\n Final Test Accuracy: {test_accuracy:.2f}%")
    
    # Classification report
    print("\n Classification Report:")
    print("=" * 80)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    
    # Cohen's Kappa
    kappa = cohen_kappa_score(y_true, y_pred)
    print(f"\n Cohen's Kappa Score: {kappa:.4f}")
    if kappa > 0.8:
        print("    Excellent agreement")
    elif kappa > 0.6:
        print("    Substantial agreement")
    elif kappa > 0.4:
        print("    Moderate agreement")
    else:
        print("   Poor agreement")
    
    # Confusion matrix
    print("\n Generating visualizations...")
    cm = plot_confusion_matrix(y_true, y_pred, class_names)
    
    # ROC curves
    mean_auc = plot_roc_curves(y_true, y_probs, class_names)
    
    # Summary
    print("\n" + "=" * 60)
    print(" FINAL RESULTS SUMMARY")
    print("=" * 60)
    print(f" Test Accuracy:     {test_accuracy:.2f}%")
    print(f" Mean AUC Score:    {mean_auc:.3f}")
    print(f" Cohen's Kappa:     {kappa:.4f}")
    print(f" Best Val Accuracy: {best_val_acc:.2f}%")
    
    # Save final model with metadata
    torch.save({
        'model_state_dict': model.state_dict(),
        'class_names': class_names,
        'test_accuracy': test_accuracy,
        'cohen_kappa': kappa,
        'mean_auc': mean_auc,
        'history': history
    }, 'final_colorectal_model.pth')
    
    print(f"\n Models saved successfully!")
    print(f"   - best_colorectal_model.pth (best weights)")
    print(f"   - final_colorectal_model.pth (with metadata)")
   
if __name__ == "__main__":
    main()
# Out:
#  Starting Colorectal Cancer Classification with EfficientNet-B3 + UNKNOWN class
# ============================================================
#  Using device: cuda
#
# ============================================================
# Creating data loaders with 70-15-15 split...
# Class counts: Counter({'01_TUMOR': 625, '02_STROMA': 625, '03_COMPLEX': 625, '04_LYMPHO': 625, '05_DEBRIS': 625, '06_MUCOSA': 625, '07_ADIPOSE': 625, '08_EMPTY': 625, 'UNKNOWN': 500})
# Total samples: 5500
# Train size: 3849, Val size: 825, Test size: 826
#
#  Dataset Information:
#    Classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY', 'UNKNOWN']
#
#  Building EfficientNet-B3 model...
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 139MB/s]
# EfficientNet-B3 with IMAGENET1K_V1 weights loaded successfully
# Total params: 11618353, Trainable params: 4476291
#
# ============================================================
#  Starting training...
# Epoch 1/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 1/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 1/40 Results:
#    Train Loss: 0.9456, Train Acc: 81.22%
#    Val Loss: 0.7450, Val Acc: 90.18%
#     New best model saved! Val Acc: 90.18%
# ----------------------------------------------------------------------
# Epoch 2/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 2/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 2/40 Results:
#    Train Loss: 0.7672, Train Acc: 89.14%
#    Val Loss: 2.1220, Val Acc: 91.03%
#     New best model saved! Val Acc: 91.03%
# ----------------------------------------------------------------------
# Epoch 3/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 3/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 3/40 Results:
#    Train Loss: 0.7102, Train Acc: 90.89%
#    Val Loss: 0.6897, Val Acc: 91.52%
#     New best model saved! Val Acc: 91.52%
# ----------------------------------------------------------------------
# Epoch 4/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 4/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 4/40 Results:
#    Train Loss: 0.6594, Train Acc: 93.62%
#    Val Loss: 0.6488, Val Acc: 92.97%
#     New best model saved! Val Acc: 92.97%
# ----------------------------------------------------------------------
# Epoch 5/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 5/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 5/40 Results:
#    Train Loss: 0.6470, Train Acc: 94.11%
#    Val Loss: 0.6622, Val Acc: 92.00%
# ----------------------------------------------------------------------
# Epoch 6/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 6/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 6/40 Results:
#    Train Loss: 0.6178, Train Acc: 95.16%
#    Val Loss: 0.7141, Val Acc: 91.15%
# ----------------------------------------------------------------------
# Epoch 7/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 7/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 7/40 Results:
#    Train Loss: 0.6054, Train Acc: 95.65%
#    Val Loss: 0.6385, Val Acc: 93.45%
#     New best model saved! Val Acc: 93.45%
# ----------------------------------------------------------------------
# Epoch 8/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 8/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 8/40 Results:
#    Train Loss: 0.5752, Train Acc: 96.85%
#    Val Loss: 0.6692, Val Acc: 93.21%
# ----------------------------------------------------------------------
# Epoch 9/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 9/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 9/40 Results:
#    Train Loss: 0.5797, Train Acc: 96.72%
#    Val Loss: 0.7171, Val Acc: 93.45%
# ----------------------------------------------------------------------
# Epoch 10/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 10/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 10/40 Results:
#    Train Loss: 0.5771, Train Acc: 96.85%
#    Val Loss: 0.6491, Val Acc: 92.85%
# ----------------------------------------------------------------------
# Epoch 11/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 11/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 11/40 Results:
#    Train Loss: 0.5584, Train Acc: 97.92%
#    Val Loss: 0.6366, Val Acc: 93.70%
#     New best model saved! Val Acc: 93.70%
# ----------------------------------------------------------------------
# Epoch 12/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 12/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 12/40 Results:
#    Train Loss: 0.5614, Train Acc: 97.50%
#    Val Loss: 0.6795, Val Acc: 93.58%
# ----------------------------------------------------------------------
# Epoch 13/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 13/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 13/40 Results:
#    Train Loss: 0.5552, Train Acc: 97.73%
#    Val Loss: 0.6311, Val Acc: 93.45%
# ----------------------------------------------------------------------
# Epoch 14/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 14/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 14/40 Results:
#    Train Loss: 0.5488, Train Acc: 98.10%
#    Val Loss: 0.6239, Val Acc: 94.06%
#     New best model saved! Val Acc: 94.06%
# ----------------------------------------------------------------------
# Epoch 15/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 15/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 15/40 Results:
#    Train Loss: 0.5424, Train Acc: 98.33%
#    Val Loss: 0.6196, Val Acc: 94.18%
#     New best model saved! Val Acc: 94.18%
# ----------------------------------------------------------------------
# Epoch 16/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 16/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 16/40 Results:
#    Train Loss: 0.5507, Train Acc: 97.71%
#    Val Loss: 0.6153, Val Acc: 94.79%
#     New best model saved! Val Acc: 94.79%
# ----------------------------------------------------------------------
# Epoch 17/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 17/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 17/40 Results:
#    Train Loss: 0.5365, Train Acc: 98.52%
#    Val Loss: 6.1111, Val Acc: 94.67%
# ----------------------------------------------------------------------
# Epoch 18/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 18/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 18/40 Results:
#    Train Loss: 0.5287, Train Acc: 98.78%
#    Val Loss: 0.6223, Val Acc: 94.18%
# ----------------------------------------------------------------------
# Epoch 19/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 19/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 19/40 Results:
#    Train Loss: 0.5249, Train Acc: 98.72%
#    Val Loss: 0.6365, Val Acc: 94.18%
# ----------------------------------------------------------------------
# Epoch 20/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 20/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 20/40 Results:
#    Train Loss: 0.5281, Train Acc: 98.80%
#    Val Loss: 0.9287, Val Acc: 93.94%
# ----------------------------------------------------------------------
# Epoch 21/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 21/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 21/40 Results:
#    Train Loss: 0.5216, Train Acc: 99.19%
#    Val Loss: 0.7655, Val Acc: 93.70%
# ----------------------------------------------------------------------
# Epoch 22/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 22/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 22/40 Results:
#    Train Loss: 0.5245, Train Acc: 98.98%
#    Val Loss: 1.0708, Val Acc: 93.94%
# ----------------------------------------------------------------------
# Epoch 23/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 23/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 23/40 Results:
#    Train Loss: 0.5233, Train Acc: 99.01%
#    Val Loss: 0.7258, Val Acc: 94.55%
# ----------------------------------------------------------------------
# Epoch 24/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 24/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 24/40 Results:
#    Train Loss: 0.5151, Train Acc: 99.43%
#    Val Loss: 0.6290, Val Acc: 94.55%
# ----------------------------------------------------------------------
# Epoch 25/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 25/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 25/40 Results:
#    Train Loss: 0.5187, Train Acc: 99.19%
#    Val Loss: 0.6378, Val Acc: 93.94%
# ----------------------------------------------------------------------
# Epoch 26/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 26/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 26/40 Results:
#    Train Loss: 0.5134, Train Acc: 99.45%
#    Val Loss: 0.6288, Val Acc: 94.79%
# ----------------------------------------------------------------------
#  Early stopping triggered after epoch 26
#
#  Best validation accuracy achieved: 94.79%
#
#  Plotting training history...
# ============================================================
#  Evaluating on test set...
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
#  Final Test Accuracy: 95.04%
#
#  Classification Report:
# ================================================================================
#               precision    recall  f1-score   support
#
#     01_TUMOR     0.9684    0.9892    0.9787        93
#    02_STROMA     0.9346    0.9709    0.9524       103
#   03_COMPLEX     0.8780    0.7826    0.8276        92
#    04_LYMPHO     0.8679    0.9787    0.9200        94
#    05_DEBRIS     0.9639    0.9195    0.9412        87
#    06_MUCOSA     1.0000    0.9794    0.9896        97
#   07_ADIPOSE     0.9907    0.9727    0.9817       110
#     08_EMPTY     0.9630    0.9873    0.9750        79
#      UNKNOWN     1.0000    0.9718    0.9857        71
#
#     accuracy                         0.9504       826
#    macro avg     0.9518    0.9503    0.9502       826
# weighted avg     0.9511    0.9504    0.9499       826
#
#
#  Cohen's Kappa Score: 0.9441
#     Excellent agreement
#
#  Generating visualizations...
# ============================================================
#  FINAL RESULTS SUMMARY
# ============================================================
#  Test Accuracy:     95.04%
#  Mean AUC Score:    0.990
#  Cohen's Kappa:     0.9441
#  Best Val Accuracy: 94.79%
#
#  Models saved successfully!
#    - best_colorectal_model.pth (best weights)
#    - final_colorectal_model.pth (with metadata)

# %%
import zipfile

file_paths = [
    '/kaggle/working/best_colorectal_model.pth',
    '/kaggle/working/final_colorectal_model.pth'
]

zip_file_path = '/kaggle/working/modelsEfficientNetB3.zip'

with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    for file in file_paths:
        zipf.write(file, arcname=file.split('/')[-1])

print("Created zip file:", zip_file_path)
# Out:
# Created zip file: /kaggle/working/modelsEfficientNetB3.zip

# %%
from IPython.display import FileLink
FileLink(r'modelsEfficientNetB3.zip')
# Out:
# /kaggle/working/modelsEfficientNetB3.zip
