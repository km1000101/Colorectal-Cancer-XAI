# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635057633867-bbb11bd336b3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1602485467114-f85820ce228f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113211800-4acbb59fc254.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1541958409-7618fd1ad26e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638051894614-a60031fc6962.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639033302448-1b98bbf802bf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637310917417-a270927f4fba.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1576442849893-92c987a8ef80.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635967200497-6a83775bf395.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635990215165-9f03a3c06d93.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638914964252-bf7ca2186a5b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1621001214537-a61cb5302e73.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636034625622-2a983466599e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1525531845240-05c911ed9940.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638140481609-ec648a2edbea.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599420186946-7b6fb4e297f0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1606772108903-340d99f0cb4f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638120663372-4a19a1c058bf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1534353436294-0dbd4bdac845.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1471897488648-5eae4ac6686b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637449011677-e5c1117422c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636557343665-dcf9adcead85.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636105146585-65a51b472c7e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637266702921-a2eae66c7f9d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635166889229-65f025e0e8f7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1557720667-093b45dde7b9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637684728060-6718af94f818.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637386755860-438286f0c242.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638128711789-78d41417da4c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636307777555-fdb6f5e71b23.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638111963063-9dc8f1afa9b9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636119829557-811b68e52981.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1586773860418-d37222d8fce3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637310925669-3bcd0a02ba10.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1629398395264-c3f4a95bcbb4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636148949037-577be4e696a1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1600288214715-7c9e3127c3c2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1592724944475-94f92ee13664.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1628182488460-0d244f7440f2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639046033583-390653f5c09a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637305500355-a3f11172cc19.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635500574974-114cb4f49759.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634734887392-84f5af6766e5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599420186946-7b6fb4e297f0 (1).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113212875-8ecf30ad2e81.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1607571183710-82fbb3b57f02.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636017427762-5a8b1bd9f684.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636402187605-02fd13865485.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638988681221-17d3c96daa09.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1590255504663-a4499750ef1e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636140095196-6cf5df0f7fe3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638987168435-e5f278c25a90.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637468658667-119776ad6c54.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634842135325-3519b715a2a6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635248426315-4f4f4f1440ff.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633354579313-7cbd8bba2641.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636806961068-6d02a5d5e32c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638963042203-e4fb5aee0d0b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1573017714772-9e1a0f92d734.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1618158649544-83c93b97377d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638137392998-cd8a1b4775b8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637311252429-634d760e08b2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637310916063-3fdcd6bb88b4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634232037688-af05e5546c5e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1606380588787-8df71f764c00.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638191646677-707fca49a03e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1544726368-8f4b5475a7e4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636110351301-dc7ab9025cd9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1518895949257-7621c3c786d7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634994479491-88608622277e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637298229921-c193d49cafb4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639031931434-e2f52577b32b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636522337224-587680b3ca77.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637264812825-8b1ce6ccb0b9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637269428203-8d38cf3409dc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1593642634367-d91a135587b5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636649314542-9ca27f901803.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1561712815-ca8c24faa5b5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635990237898-5a2229089456.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634467164575-74a2a342b43e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1543952533-1152a7c1a39c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599420186946-7b6fb4e297f0 (2).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635866869385-fabb68f0dea0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1623039925698-1f96229b1a51.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639008941188-49dbd16179c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636123857822-e1c86b672db3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633764088641-833af773e177.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634060690089-7df40b25cf84.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636482095080-4033a0cd51de.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113090286-3318ea2d24ae.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1612052828302-b10880f8e3db.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1621609764095-b32bbe35cf3a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636006988787-83d60e19f7e4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1629897068815-93f9857b872f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636647780757-223e17e31f81.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634834506368-dd46ec21438c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1612966809559-dac0bed38b6a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637271119937-5852df38427a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635998230603-c1ed2dfafdf5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637352569958-2f6a28679d3c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639021110992-e12c8eb31f92.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636588118142-775d528a61a7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633354580825-a97c20319206.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638131169827-cb619350b2a0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635232958036-47d621343f0d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635876988521-35f66cda80ab.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1517649763962-0c623066013b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637406301895-1ca32a5d0a16.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1521706862577-47b053587f91.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636146321825-c8dd069be6ee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1632303746677-8b9957f532ec.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1503023345310-bd7c1de61c7d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636027572844-0ef78ee54c6d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634064415653-ee82705f5451.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1600358360892-dc1d87cf6a60.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634978160062-dbbb1751f786.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636434593825-de7adbff82d1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1511936606692-5e0d73f6b638.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1516746924755-babd21844370.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635505290386-1c01faedd8c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635965750082-d69c3e8b79bd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1567316106249-b2ecaeefdade.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634590430581-aabcbf1cf5fe.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636126175692-ef9f1d41a038.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1622028715355-ec58f12a7f9c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635484868888-f29fe141733a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1497215728101-856f4ea42174.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637088533459-253592eb65be.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638108820168-77c13bd437bd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1631912757195-5abf3e3b9384.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635461742809-95b4f1365a7d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635291215591-dc320946dddb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637447032294-c3bbeada43f9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1574387313309-7c2292978b8c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634568006374-f7eea32e4b52.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637248921272-55cb27d12a31.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636364081585-1d2d957d3295.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634312977603-af4396eb24cb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1471899236350-e3016bf1e69e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634644099092-734658d5e286.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635333607240-1397692acdd2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638985787285-46f05ff063f2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1574672280600-4accfa5b6f98.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637966495649-c102312261c7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1630493391413-d96641b10a97.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637045486754-92ebb723eef9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637361973734-5faf9b1e923e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638981676264-8a590bdc42f8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636100316656-c50ac55abe92.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634840844784-5e2e0485f8a6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635514695347-05806de5be33.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1471897488648-5eae4ac6686b (1).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1504297050568-910d24c426d3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1602126303242-0228a05827b4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1610694308659-fd4340288ba7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637717256696-a0204d03a8fe.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635480180600-1f0413696374.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638533760719-81450c3cf1a0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636118155446-e9ec9187aa1f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637361891315-2e5e11096078.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635546037630-107f3f848257.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634544190292-65c22300dcae.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635958030830-f0bbd21d919c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635079959001-69736953f90f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634053672942-d291994da3dd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638195157505-5a4b33446acb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637275769153-b5fb9e5647f1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1623494030543-2ef3fd71e8c2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638063761285-08f6a2f796f5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1524526967094-4448faba6b81.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1541480333465-b09786ad8ac6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113215719-e9cc39f594b2 (1).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633114128174-2f8aa49759b0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637250060437-eaad0291deff.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635352285792-dbef0d9f570a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1544038659-12337883d216.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1588467850695-a898367ce465.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1558005137-d9619a5c539f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1515592559813-3f7dff97e185.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1628255591287-2147e76fe3f0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1514517220017-8ce97a34a7b6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635502152437-18e0c22de313.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637309194017-8ac73fa46c92.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1615871154954-3a50b273dbf6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635179850659-da5451a9416c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638153867870-daadae81acb5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1549867679-8f092bfe5329.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639038417583-4cca95fe9e0b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636032442998-e69650e970bf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1606512072892-e7b92d25f91a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638823646453-8981014119de.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635702961555-8c700d0c79f0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636148851950-5cf659c66ef1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633354581775-cf8c4c71361c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1631507467986-bc98ba4ed1b3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633993365492-0828ece5c0ed.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637338740872-f2c1979a264f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636137088104-ab8cbb30d645.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637478847587-1740c47f65dc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636189395464-c277f6f6f8ad.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636725691774-e9c7cfb150ab.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634834576400-56f5e1ad8db8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636318302022-0eea94e461b8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1558090056-c994bfb27e14.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1593642702821-c8da6771f0c6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637722873821-3196d8c0f74f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1628498048001-2f4635107dbc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1488900128323-21503983a07e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635994481056-72caf67341dd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634616195757-66d5e402058d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635965450325-db9599123c9b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1557518016-20592fc7adbb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636517521239-4bb86552dfb3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1533602747409-1f3dea118ac8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627642494854-68c8a0779fce.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1593642702909-dec73df255d7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638825183364-01e8b64b00e0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635966082044-1ad16e64bc93.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638164659039-77870de9637b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1509715513011-e394f0cb20c4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635098996167-bd4cc370a289.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637004253818-d3072efc73fe.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635195867433-590941c6e9c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637406305013-e1b0db816c34.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1565138146061-e29b079736c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1564369790608-e7fefe819dec.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636126175948-96ccc89b9c45.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634402795073-b491388bf6ee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1540137779703-594db0107a4b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635355435138-16c1fa22ad9f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1569597408915-cb395eee98b0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638063174485-67f7bb1f2aae.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633113088942-99089f4abffa.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1499636136210-6f4ee915583e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635452066377-6df9b3529b33.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638115275109-49c36d55b3a5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1550686041-366ad85a1355.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635083096194-c741123da741.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636142972514-0c75fc584a12.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635352263535-167aac6cc044.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636139677414-306c924e79a2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635344902053-3a9e4a5506d2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636038301178-0534cabba3db.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634589327639-97c05eb56a82.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635702959232-9dde3332384e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636106020064-2658eb589d36.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1604900881431-781565ae8d91.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635931907849-f2109d3aecf3.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637045713939-321b2bc8ed88.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636132644036-79b25423bce9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1520901311353-76c9032606fb.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1496449903678-68ddcb189a24.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637268852311-00c8259636bc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634562210417-46cce4febb86.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636165815614-4ae073913f68.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634158930632-5fe117ef3574.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1604585728556-1749cfd13491.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633490822755-2483d81cab8a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634521991558-a1f4dbd641db.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638094484540-3ee0875aaca5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638068969707-4642a41e901c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637461979290-120a2d8e5de5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635983936376-154277d90673.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633114127824-14b3207d7d74.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635005492534-fb34f77c2202.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637464947514-e2dfc95c5f86.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1547574677-78ac9141ed6a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636124462545-a03553f4a4d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1470058869958-2a77ade41c02.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1598805116430-4a0736a3114a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637754614390-11539bca3578.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634274685639-752302e49d97.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635683844800-fe8473ac25c2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639001197863-d95742e45858.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638075241360-a6550ef0ade9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638038925474-83bfbf1a7206.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635674367453-924e9a6e7517.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636093666353-a550fa61150c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1557100955-93b2fb57c317.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1562374184-a71b175917b0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636307777550-3a5d2bdf69a1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636059863611-aa0715fc9f48.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633114073758-c4be9aeb15ac.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636158926664-121bd598e8a7.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637768441214-c78ef49049b2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637441083501-40d682b400c4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637452313272-9f5855b5f2bc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637344970134-ee0c02e864b5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633034147183-34371efff7ad.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636962646984-b8ac780efda6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1599669846660-945c5c775181.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638193625184-fd7b6d313eb9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639030089338-caedb56ff4d8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638039363096-71dc00d7bd3c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1581456495146-65a71b2c8e52.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636886519725-6a048800b5b4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637712088515-d729d807a7b2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639035197300-a03f3bd3fad2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1506459225024-1428097a7e18.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636205676986-8ad0081a792d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1593642633279-1796119d5482.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638157546153-fe37f0886cd5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635343905663-28b198347d7b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1610428987046-6e3c12f9d0fe.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638990601165-25b17ae12f95.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638975928080-2a128460e7b1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637580981126-881fd2ce493f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636642370467-93d378493021.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1576567559946-60e4729da9f8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637466828537-8124def82012.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633749130879-5d8c9f228e5f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1464695110811-dcf3903dc2f4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634226363964-98187a7e55cf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637996457841-a819a6046dd9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636017333880-6b88ce2c8f3a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627562369418-e7ccfc3958c8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637740000601-71aaf0981bc6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638087857333-08ea9b5c30c0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638988319382-90e61be77c59.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638987158215-dbaa874ed068.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637716271380-ac131fc689d4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1610112260132-ea7495ef1b61.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635108007076-47530881e2ac.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635321594544-7dbc56d3ed52.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1512351735230-a07ebdf5b5e1.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635073878554-1d35fa316c4f.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1560851691-ebb64b584d3d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634582989477-a237f47cde93.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638074645949-0f1383f6ccee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1609738394507-57348ec4e540.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1547574832-c6b67ae80f07.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1628300588354-2d76485c8364.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1604948209002-73b1b0235ec9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638188955953-55ed6325eeff.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1633399207250-03324b6067a0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1630465515450-fd8eec42e228.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634698046213-54daa6bf25ff.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636033105899-b18d32211913.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636149841788-795891beb81a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635504979606-b3e2fb1b07f2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1501446393885-828292b7670a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636232608972-426a145d3752.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636307780559-c876ff1ef9b0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634274684750-450032cefa7a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637262067120-e91737ed40a0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635087940500-bc49d0cd6d3a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635846391361-188bd8eecc2d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638164668274-62f5aca12298.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634244106844-107aa05a2df0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637441210934-cea27d639b0e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638115016574-f84d2e491df4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634148529256-c4eea4b56aab.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636333134183-e27836b3d4be.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638088636176-591de4dc9287.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635951485250-9e6e54bb896b.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1572303019843-8b5e58984d4e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637310929373-c21e999ffd2e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635955554711-f942bb828939.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1541252260730-0412e8e2108e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637274503062-bceca456c9bd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635330409777-b3535af024ee.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636139565467-fa3e429261ad.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636071659269-b796a1b56b9d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635702961556-fd45d5aed278.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1547979682-ee3acc7a3f13.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1529218402470-5dec8fea0761.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1499195333224-3ce974eecb47.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634588081226-123954b41979.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634307449316-e85197d0d4f9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1624352310258-fc59036a947c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635058801600-9db79aff5ccc.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636014470337-fd160bee5530.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635768883237-1bb8cc584978.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636181319910-5ad366ca8d36.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1485470733090-0aae1788d5af.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1461896836934-ffe607ba8211.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635807012936-540d20f59e34.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637479758719-a8f1241435e8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635913231119-7148f7c6ad8c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1627110563676-7f534cbab296.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638991933262-742d053687e6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638885912790-84ec37bf7c37.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634750089642-49e19037b78d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638108799408-81959640913e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1433162653888-a571db5ccccf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635946918595-2ebb330f8fab.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638991662664-607e16a304e9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637076530012-b2443f5fecef.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635263864583-a8b424150e82.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635792415856-dd608995bcd5.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1516638670706-e28e9118fa9a.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1581798269145-7512508289b9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635055658722-494d99b8aebd.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637262448017-0fbbec87a898.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639021110987-f8e727d5f43e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635961749515-177ce449cfb2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1632197853542-cae243b49062.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1471086569966-db3eebc25a59.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637743965368-263b189397ac.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635967198465-853200fd84d0.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636017818578-8e856ff67713.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638989420853-a6437f7a0d2c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634589327639-97c05eb56a82 (1).jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636149076015-a7cb13e40ab2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637703283014-7c64ec1d7085.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634003308715-7f3b46638942.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1618447977868-d26948d88c89.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634291934402-7968f44a2939.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1503162894963-8c333941fb01.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1458571037713-913d8b481dc6.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1538883689728-2c32af36a313.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1631945387381-d83bbe39cb54.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1606590056137-c3c4f42074d4.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1636355761620-712e88f86ade.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1623268202161-8c32c7e213cf.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634149944809-106fe7210c51.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635965686975-b140d00d3b0d.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1608516679567-092f1139f4e8.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1619617345083-9f3857455d2e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1634391058723-c125b22f3217.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1625604479008-e1bf71297898.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637179709448-e03199d05f6e.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1637484581501-05bc3d6725be.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1635756837851-d3b6edbaa11c.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1538108149393-fbbd81895907.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1638086164779-ee3799dd1da9.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1639048759545-07cdc2fc63e2.jpg
# /kaggle/input/unsplash-random-images-collection/unsplash-images-collection/photo-1556648011-e01aca870a81.jpg
# ...
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12F47_CRC-Prim-HE-04_036.tif_Row_901_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1255D_CRC-Prim-HE-05_032.tif_Row_1051_Col_4651.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/128A_CRC-Prim-HE-06_004.tif_Row_2101_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/139ED_CRC-Prim-HE-07.tif_Row_901_Col_3151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15793_CRC-Prim-HE-03_012.tif_Row_1351_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16DBD_CRC-Prim-HE-03_012.tif_Row_451_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12009_CRC-Prim-HE-07.tif_Row_751_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15CE2_CRC-Prim-HE-06_004.tif_Row_1_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11472_CRC-Prim-HE-07.tif_Row_1201_Col_2701.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15CB4_CRC-Prim-HE-03_012.tif_Row_751_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/14A0B_CRC-Prim-HE-03_012.tif_Row_451_Col_2851.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16997_CRC-Prim-HE-03_012.tif_Row_3001_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12EC3_CRC-Prim-HE-10_020.tif_Row_301_Col_2551.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13135_CRC-Prim-HE-03_012.tif_Row_4201_Col_2251.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1388E_CRC-Prim-HE-07.tif_Row_751_Col_3301.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12BD2_CRC-Prim-HE-10_020.tif_Row_1051_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1455D_CRC-Prim-HE-03_012.tif_Row_2251_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1721F_CRC-Prim-HE-06_004.tif_Row_301_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15D63_CRC-Prim-HE-03_012.tif_Row_4201_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1308F_CRC-Prim-HE-05_032.tif_Row_1051_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11E96_CRC-Prim-HE-05_032.tif_Row_1501_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/125EE_CRC-Prim-HE-03_012.tif_Row_4051_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1225C_CRC-Prim-HE-03_012.tif_Row_3151_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1657D_CRC-Prim-HE-06_004.tif_Row_1201_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11DC9_CRC-Prim-HE-05_032.tif_Row_1_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/131EA_CRC-Prim-HE-10_020.tif_Row_451_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1040C_CRC-Prim-HE-05_032.tif_Row_1051_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11315_CRC-Prim-HE-03_012.tif_Row_1951_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15770_CRC-Prim-HE-03_012.tif_Row_1801_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/140F8_CRC-Prim-HE-03_012.tif_Row_3301_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/151BB_CRC-Prim-HE-06_004.tif_Row_1051_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/120B9_CRC-Prim-HE-06_004.tif_Row_601_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/10CB3_CRC-Prim-HE-03_012.tif_Row_151_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/10C21_CRC-Prim-HE-05_032.tif_Row_1201_Col_3901.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16107_CRC-Prim-HE-05_032.tif_Row_1201_Col_2701.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16D7C_CRC-Prim-HE-07.tif_Row_601_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13D1_CRC-Prim-HE-07.tif_Row_751_Col_1801.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12124_CRC-Prim-HE-03_012.tif_Row_1051_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1577D_CRC-Prim-HE-05_032.tif_Row_451_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12A3F_CRC-Prim-HE-06_004.tif_Row_1951_Col_2551.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12855_CRC-Prim-HE-05_032.tif_Row_1351_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/173F5_CRC-Prim-HE-05_032.tif_Row_751_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/14020_CRC-Prim-HE-03_012.tif_Row_1951_Col_2251.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16041_CRC-Prim-HE-07.tif_Row_1201_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13366_CRC-Prim-HE-05_032.tif_Row_1951_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/154D3_CRC-Prim-HE-03_012.tif_Row_1_Col_2551.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16031_CRC-Prim-HE-03_012.tif_Row_751_Col_2701.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1350B_CRC-Prim-HE-06_004.tif_Row_2101_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11808_CRC-Prim-HE-07.tif_Row_1051_Col_4051.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1342D_CRC-Prim-HE-06_004.tif_Row_901_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12954_CRC-Prim-HE-03_012.tif_Row_151_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11A6D_CRC-Prim-HE-06_004.tif_Row_1801_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/153E8_CRC-Prim-HE-04_036.tif_Row_1051_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11431_CRC-Prim-HE-05_032.tif_Row_1501_Col_3751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/14C5B_CRC-Prim-HE-03_012.tif_Row_1201_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1003E_CRC-Prim-HE-05_032.tif_Row_1951_Col_2701.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1428D_CRC-Prim-HE-06_004.tif_Row_601_Col_1951.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13C88_CRC-Prim-HE-06_004.tif_Row_2701_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/128CB_CRC-Prim-HE-06_004.tif_Row_151_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13756_CRC-Prim-HE-05_032.tif_Row_301_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1437_CRC-Prim-HE-10_020.tif_Row_601_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1277B_CRC-Prim-HE-05_032.tif_Row_1801_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16822_CRC-Prim-HE-06_004.tif_Row_1351_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13A66_CRC-Prim-HE-06_004.tif_Row_1951_Col_601.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/128EA_CRC-Prim-HE-07.tif_Row_1_Col_2251.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13A2D_CRC-Prim-HE-03_012.tif_Row_2251_Col_1.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/17345_CRC-Prim-HE-06_004.tif_Row_2551_Col_901.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13C7E_CRC-Prim-HE-10_020.tif_Row_1_Col_301.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16932_CRC-Prim-HE-10_020.tif_Row_901_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/140C1_CRC-Prim-HE-10_020.tif_Row_151_Col_2851.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/159AD_CRC-Prim-HE-06_004.tif_Row_1351_Col_1201.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11CF8_CRC-Prim-HE-06_004.tif_Row_751_Col_2101.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/10232_CRC-Prim-HE-04_036.tif_Row_451_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/12F9D_CRC-Prim-HE-03_012.tif_Row_3001_Col_451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16613_CRC-Prim-HE-06_004.tif_Row_2551_Col_1501.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/107C9_CRC-Prim-HE-06_004.tif_Row_151_Col_2701.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13E1E_CRC-Prim-HE-03_012.tif_Row_1501_Col_1051.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15A6B_CRC-Prim-HE-05_032.tif_Row_751_Col_3901.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11B32_CRC-Prim-HE-05_032.tif_Row_601_Col_2851.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15_CRC-Prim-HE-03_012.tif_Row_751_Col_1801.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16E7E_CRC-Prim-HE-07.tif_Row_751_Col_1951.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1585F_CRC-Prim-HE-05_032.tif_Row_1_Col_4351.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/14D69_CRC-Prim-HE-06_004.tif_Row_2101_Col_1351.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/173F8_CRC-Prim-HE-07.tif_Row_1051_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1591D_CRC-Prim-HE-06_004.tif_Row_601_Col_751.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/11A64_CRC-Prim-HE-06_004.tif_Row_2701_Col_151.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16189_CRC-Prim-HE-05_032.tif_Row_301_Col_3451.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/16A75_CRC-Prim-HE-07.tif_Row_451_Col_2851.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/15B72_CRC-Prim-HE-03_012.tif_Row_2251_Col_2401.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/13AF7_CRC-Prim-HE-10_020.tif_Row_601_Col_1651.tif
# /kaggle/input/colorectal-histology-mnist/kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000/07_ADIPOSE/1330F_CRC-Prim-HE-05_032.tif_Row_301_Col_2701.tif

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms, models
import torchvision.models as models
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import seaborn as sns
from PIL import Image
import os
from collections import Counter
import warnings
import gc
from tqdm.auto import tqdm
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

class ColorectalCancerDataset(Dataset):
    def __init__(self, root_dir, transform=None, unknown_dir=None, max_unknown=None):
        """
        root_dir: directory containing the 8 colorectal class folders.
        unknown_dir: directory containing random/unsupervised images (Unsplash).
        All images in unknown_dir are labeled as 'UNKNOWN'.
        """
        self.root_dir = root_dir
        self.unknown_dir = unknown_dir
        self.transform = transform
        
        # 8 colorectal classes + 1 UNKNOWN
        self.classes = [
            '01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO',
            '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY',
            'UNKNOWN'
        ]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        
        self.samples = []
        self.class_counts = Counter()
        
        # Original 8 classes from colorectal dataset
        for class_name in self.classes:
            if class_name == 'UNKNOWN':
                continue
            class_path = os.path.join(root_dir, class_name)
            if os.path.exists(class_path):
                class_images = []
                for img_name in os.listdir(class_path):
                    if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.tif')):
                        img_path = os.path.join(class_path, img_name)
                        class_images.append((img_path, self.class_to_idx[class_name]))
                
                self.samples.extend(class_images)
                self.class_counts[class_name] = len(class_images)
        
        # UNKNOWN class from Unsplash random images folder (flat directory)
        if self.unknown_dir is not None and os.path.exists(self.unknown_dir):
            unknown_images = []
            for img_name in os.listdir(self.unknown_dir):
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.tif')):
                    img_path = os.path.join(self.unknown_dir, img_name)
                    unknown_images.append((img_path, self.class_to_idx['UNKNOWN']))
            
            # Optionally cap number of unknowns so they don't dominate
            if max_unknown is not None:
                unknown_images = unknown_images[:max_unknown]
            
            self.samples.extend(unknown_images)
            self.class_counts['UNKNOWN'] = len(unknown_images)
        
        print("Class counts:", self.class_counts)
        print("Total samples:", len(self.samples))
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        try:
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            return image, label
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a dummy image in case of error
            dummy_image = Image.new('RGB', (224, 224), color='black')
            if self.transform:
                dummy_image = self.transform(dummy_image)
            return dummy_image, label

class DenseNetClassifier(nn.Module):
    def __init__(self, num_classes=9, dropout_rate=0.5):
        super(DenseNetClassifier, self).__init__()
        
        # Load pretrained DenseNet121 with ImageNet weights [web:54][web:56]
        try:
            self.backbone = models.densenet121(weights="IMAGENET1K_V1")
            print("DenseNet121 with IMAGENET1K_V1 weights loaded successfully")
        except Exception as e:
            print("Error loading DenseNet121 pretrained weights:", e)
            raise
        
        # Freeze early layers for stable training
        for param in list(self.backbone.parameters())[:-30]:
            param.requires_grad = False
        
        # Replace classifier (DenseNet121 uses 'classifier' as final layer) [web:59][web:61]
        in_features = self.backbone.classifier.in_features
        self.backbone.classifier = nn.Sequential(
            nn.Dropout(p=dropout_rate),
            nn.Linear(in_features, 512),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),
            nn.Dropout(p=dropout_rate * 0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(256),
            nn.Dropout(p=dropout_rate * 0.3),
            nn.Linear(256, num_classes)
        )
    
    def forward(self, x):
        return self.backbone(x)

class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.001, restore_best_weights=True):
        self.patience = patience
        self.min_delta = min_delta
        self.restore_best_weights = restore_best_weights
        self.best_loss = None
        self.counter = 0
        self.best_weights = None
        
    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(model)
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.save_checkpoint(model)
        else:
            self.counter += 1
            
        if self.counter >= self.patience:
            if self.restore_best_weights and self.best_weights is not None:
                model.load_state_dict(self.best_weights)
            return True
        return False
    
    def save_checkpoint(self, model):
        self.best_weights = {k: v.clone() for k, v in model.state_dict().items()}

def get_transforms():
    train_transform = transforms.Compose([
        transforms.Resize((224, 224)),  
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
        transforms.RandomApply([transforms.GaussianBlur(kernel_size=3)], p=0.2),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    val_test_transform = transforms.Compose([
        transforms.Resize((224, 224)), 
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    return train_transform, val_test_transform

def create_data_loaders(dataset_dir, batch_size=32, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15,
                        unknown_dir=None, max_unknown=None):
    """
    Create train, validation, and test data loaders with 70-15-15 split
    including UNSPLASH random images as UNKNOWN class.
    """
    print("Creating data loaders with 70-15-15 split...")
    
    # Get transforms
    train_transform, val_test_transform = get_transforms()
    
    # Load dataset once with no transform
    full_dataset = ColorectalCancerDataset(
        dataset_dir,
        transform=None,
        unknown_dir=unknown_dir,
        max_unknown=max_unknown
    )
    
    # Calculate split sizes
    total_size = len(full_dataset)
    train_size = int(train_ratio * total_size)
    val_size = int(val_ratio * total_size)
    test_size = total_size - train_size - val_size
    
    # Random split
    generator = torch.Generator().manual_seed(42)
    train_dataset, val_dataset, test_dataset = random_split(
        full_dataset, [train_size, val_size, test_size], generator=generator
    )
    
    # Assign transforms to each split
    train_dataset.dataset.transform = train_transform
    val_dataset.dataset.transform = val_test_transform
    test_dataset.dataset.transform = val_test_transform
    
    # Create data loaders 
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, 
        num_workers=0, pin_memory=True, drop_last=True
    )
    val_loader = DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, 
        num_workers=0, pin_memory=True
    )
    test_loader = DataLoader(
        test_dataset, batch_size=batch_size, shuffle=False, 
        num_workers=0, pin_memory=True
    )
    
    print(f"Train size: {len(train_dataset)}, Val size: {len(val_dataset)}, Test size: {len(test_dataset)}")
    return train_loader, val_loader, test_loader, full_dataset.classes

def train_model(model, train_loader, val_loader, device, num_epochs=40):
    # Loss function with label smoothing
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    
    # Optimizer - AdamW with weight decay
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    
    # Learning rate scheduler
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)
    
    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.001)
    
    # History tracking
    history = {
        'train_loss': [], 'train_acc': [],
        'val_loss': [], 'val_acc': []
    }
    
    best_val_acc = 0.0
    
    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0
        
        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')
        for batch_idx, (data, target) in enumerate(train_pbar):
            data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            train_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            train_total += target.size(0)
            train_correct += (predicted == target).sum().item()
            
            # Update progress bar
            train_pbar.set_postfix({
                'Loss': f'{loss.item():.4f}',
                'Acc': f'{100.*train_correct/train_total:.2f}%'
            })
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]')
            for data, target in val_pbar:
                data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
                output = model(data)
                loss = criterion(output, target)
                
                val_loss += loss.item()
                _, predicted = torch.max(output.data, 1)
                val_total += target.size(0)
                val_correct += (predicted == target).sum().item()
                
                val_pbar.set_postfix({
                    'Loss': f'{loss.item():.4f}',
                    'Acc': f'{100.*val_correct/val_total:.2f}%'
                })
        
        # Calculate metrics
        train_loss_avg = train_loss / len(train_loader)
        train_acc = 100. * train_correct / train_total
        val_loss_avg = val_loss / len(val_loader)
        val_acc = 100. * val_correct / val_total
        
        # Update history
        history['train_loss'].append(train_loss_avg)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss_avg)
        history['val_acc'].append(val_acc)
        
        print(f'\n Epoch {epoch+1}/{num_epochs} Results:')
        print(f'   Train Loss: {train_loss_avg:.4f}, Train Acc: {train_acc:.2f}%')
        print(f'   Val Loss: {val_loss_avg:.4f}, Val Acc: {val_acc:.2f}%')
        
        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'best_colorectal_model.pth')
            print(f'    New best model saved! Val Acc: {best_val_acc:.2f}%')
        
        print('-' * 70)
        
        # Learning rate scheduling
        scheduler.step()
        
        # Early stopping
        if early_stopping(val_loss_avg, model):
            print(f' Early stopping triggered after epoch {epoch+1}')
            break
        
        # Memory cleanup
        if epoch % 10 == 0:
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
    
    return history, best_val_acc

def evaluate_model(model, test_loader, device, class_names):
    model.eval()
    all_preds = []
    all_targets = []
    all_probs = []
    
    with torch.no_grad():
        test_pbar = tqdm(test_loader, desc='Evaluating')
        for data, target in test_pbar:
            data, target = data.to(device, non_blocking=True), target.to(device, non_blocking=True)
            output = model(data)
            probs = torch.softmax(output, dim=1)
            _, predicted = torch.max(output, 1)
            
            all_preds.extend(predicted.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())
    
    return np.array(all_preds), np.array(all_targets), np.array(all_probs)

def plot_training_history(history):
    plt.style.use('default')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    
    # Plot training & validation accuracy
    epochs = range(1, len(history['train_acc']) + 1)
    ax1.plot(epochs, history['train_acc'], 'b-', label='Training Accuracy', linewidth=2)
    ax1.plot(epochs, history['val_acc'], 'r-', label='Validation Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Accuracy (%)', fontsize=12)
    ax1.legend(fontsize=10)
    ax1.grid(True, alpha=0.3)
    ax1.set_ylim([0, 100])
    
    # Plot training & validation loss
    ax2.plot(epochs, history['train_loss'], 'b-', label='Training Loss', linewidth=2)
    ax2.plot(epochs, history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
    ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Loss', fontsize=12)
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Number of Samples'})
    plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    return cm

def plot_roc_curves(y_true, y_probs, class_names):
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=range(n_classes))
    
    plt.figure(figsize=(14, 10))
    colors = plt.cm.Set3(np.linspace(0, 1, n_classes))
    
    mean_auc = 0
    for i, (class_name, color) in enumerate(zip(class_names, colors)):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
        roc_auc = auc(fpr, tpr)
        mean_auc += roc_auc
        plt.plot(fpr, tpr, color=color, lw=3, 
                label=f'{class_name} (AUC = {roc_auc:.3f})')
    
    mean_auc /= n_classes
    plt.plot([0, 1], [0, 1], 'k--', lw=2, alpha=0.8, label='Random Classifier (AUC = 0.500)')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title(f'ROC Curves - Multi-class Classification\nMean AUC = {mean_auc:.3f}', 
              fontsize=14, fontweight='bold')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    return mean_auc

def main():
    # Path for colorectal histology MNIST dataset
    DATASET_DIR = '/kaggle/input/colorectal-histology-mnist/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000'
    
    # Path for Unsplash random images dataset (flat folder with images)
    UNSPLASH_DIR = '/kaggle/input/unsplash-random-images-collection/unsplash-images-collection'
    
    BATCH_SIZE = 32  
    NUM_EPOCHS = 40  
    
    print(" Starting Colorectal Cancer Classification with DenseNet121 + UNKNOWN class")
    print("=" * 60)
    
    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f" Using device: {device}")
    
    # Create data loaders with 70-15-15 split
    print("\n" + "=" * 60)
    train_loader, val_loader, test_loader, class_names = create_data_loaders(
        DATASET_DIR,
        BATCH_SIZE,
        train_ratio=0.7,
        val_ratio=0.15,
        test_ratio=0.15,
        unknown_dir=UNSPLASH_DIR,
        max_unknown=500  # adjust or remove cap as you like
    )
    
    print(f"\n Dataset Information:")
    print(f"   Classes: {class_names}")
    
    # Create model (num_classes inferred from class_names length)
    print(f"\n Building DenseNet121 model...")
    model = DenseNetClassifier(num_classes=len(class_names), dropout_rate=0.5)
    model.to(device)
    
    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Total params: {total_params}, Trainable params: {trainable_params}")
    
    # Train model
    print("\n" + "=" * 60)
    print(" Starting training...")
    history, best_val_acc = train_model(model, train_loader, val_loader, device, NUM_EPOCHS)
    
    # Load best model for evaluation
    model.load_state_dict(torch.load('best_colorectal_model.pth'))
    print(f"\n Best validation accuracy achieved: {best_val_acc:.2f}%")
    
    # Plot training history
    print("\n Plotting training history...")
    plot_training_history(history)
    
    # Evaluate on test set
    print("\n" + "=" * 60)
    print(" Evaluating on test set...")
    y_pred, y_true, y_probs = evaluate_model(model, test_loader, device, class_names)
    
    # Calculate final test accuracy
    test_accuracy = (y_pred == y_true).mean() * 100
    print(f"\n Final Test Accuracy: {test_accuracy:.2f}%")
    
    # Classification report
    print("\n Classification Report:")
    print("=" * 80)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    
    # Cohen's Kappa
    kappa = cohen_kappa_score(y_true, y_pred)
    print(f"\n Cohen's Kappa Score: {kappa:.4f}")
    if kappa > 0.8:
        print("    Excellent agreement")
    elif kappa > 0.6:
        print("    Substantial agreement")
    elif kappa > 0.4:
        print("    Moderate agreement")
    else:
        print("   Poor agreement")
    
    # Confusion matrix
    print("\n Generating visualizations...")
    cm = plot_confusion_matrix(y_true, y_pred, class_names)
    
    # ROC curves
    mean_auc = plot_roc_curves(y_true, y_probs, class_names)
    
    # Summary
    print("\n" + "=" * 60)
    print(" FINAL RESULTS SUMMARY")
    print("=" * 60)
    print(f" Test Accuracy:     {test_accuracy:.2f}%")
    print(f" Mean AUC Score:    {mean_auc:.3f}")
    print(f" Cohen's Kappa:     {kappa:.4f}")
    print(f" Best Val Accuracy: {best_val_acc:.2f}%")
    
    # Save final model with metadata
    torch.save({
        'model_state_dict': model.state_dict(),
        'class_names': class_names,
        'test_accuracy': test_accuracy,
        'cohen_kappa': kappa,
        'mean_auc': mean_auc,
        'history': history
    }, 'final_colorectal_model.pth')
    
    print(f"\n Models saved successfully!")
    print(f"   - best_colorectal_model.pth (best weights)")
    print(f"   - final_colorectal_model.pth (with metadata)")
   
if __name__ == "__main__":
    main()
# Out:
#  Starting Colorectal Cancer Classification with DenseNet121 + UNKNOWN class
# ============================================================
#  Using device: cuda
#
# ============================================================
# Creating data loaders with 70-15-15 split...
# Class counts: Counter({'01_TUMOR': 625, '02_STROMA': 625, '03_COMPLEX': 625, '04_LYMPHO': 625, '05_DEBRIS': 625, '06_MUCOSA': 625, '07_ADIPOSE': 625, '08_EMPTY': 625, 'UNKNOWN': 500})
# Total samples: 5500
# Train size: 3849, Val size: 825, Test size: 826
#
#  Dataset Information:
#    Classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY', 'UNKNOWN']
#
#  Building DenseNet121 model...
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 122MB/s]
# DenseNet121 with IMAGENET1K_V1 weights loaded successfully
# Total params: 7613833, Trainable params: 1338377
#
# ============================================================
#  Starting training...
# Epoch 1/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 1/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 1/40 Results:
#    Train Loss: 0.9881, Train Acc: 79.32%
#    Val Loss: 0.7159, Val Acc: 91.76%
#     New best model saved! Val Acc: 91.76%
# ----------------------------------------------------------------------
# Epoch 2/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 2/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 2/40 Results:
#    Train Loss: 0.7663, Train Acc: 90.21%
#    Val Loss: 0.6589, Val Acc: 93.45%
#     New best model saved! Val Acc: 93.45%
# ----------------------------------------------------------------------
# Epoch 3/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 3/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 3/40 Results:
#    Train Loss: 0.6907, Train Acc: 92.58%
#    Val Loss: 0.6351, Val Acc: 93.94%
#     New best model saved! Val Acc: 93.94%
# ----------------------------------------------------------------------
# Epoch 4/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 4/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 4/40 Results:
#    Train Loss: 0.6582, Train Acc: 93.72%
#    Val Loss: 0.6255, Val Acc: 94.67%
#     New best model saved! Val Acc: 94.67%
# ----------------------------------------------------------------------
# Epoch 5/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 5/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 5/40 Results:
#    Train Loss: 0.6277, Train Acc: 95.36%
#    Val Loss: 0.6148, Val Acc: 95.52%
#     New best model saved! Val Acc: 95.52%
# ----------------------------------------------------------------------
# Epoch 6/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 6/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 6/40 Results:
#    Train Loss: 0.6103, Train Acc: 95.49%
#    Val Loss: 0.5961, Val Acc: 95.52%
# ----------------------------------------------------------------------
# Epoch 7/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 7/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 7/40 Results:
#    Train Loss: 0.5788, Train Acc: 97.34%
#    Val Loss: 0.6103, Val Acc: 95.39%
# ----------------------------------------------------------------------
# Epoch 8/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 8/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 8/40 Results:
#    Train Loss: 0.5661, Train Acc: 97.68%
#    Val Loss: 0.6068, Val Acc: 94.91%
# ----------------------------------------------------------------------
# Epoch 9/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 9/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 9/40 Results:
#    Train Loss: 0.5566, Train Acc: 98.05%
#    Val Loss: 0.6401, Val Acc: 93.58%
# ----------------------------------------------------------------------
# Epoch 10/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 10/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 10/40 Results:
#    Train Loss: 0.5551, Train Acc: 97.97%
#    Val Loss: 0.6309, Val Acc: 94.42%
# ----------------------------------------------------------------------
# Epoch 11/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 11/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 11/40 Results:
#    Train Loss: 0.5410, Train Acc: 98.59%
#    Val Loss: 0.6101, Val Acc: 94.91%
# ----------------------------------------------------------------------
# Epoch 12/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 12/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 12/40 Results:
#    Train Loss: 0.5361, Train Acc: 98.78%
#    Val Loss: 0.6061, Val Acc: 95.39%
# ----------------------------------------------------------------------
# Epoch 13/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 13/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 13/40 Results:
#    Train Loss: 0.5394, Train Acc: 98.67%
#    Val Loss: 0.6202, Val Acc: 95.27%
# ----------------------------------------------------------------------
# Epoch 14/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 14/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 14/40 Results:
#    Train Loss: 0.5269, Train Acc: 99.22%
#    Val Loss: 0.6172, Val Acc: 95.03%
# ----------------------------------------------------------------------
# Epoch 15/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 15/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 15/40 Results:
#    Train Loss: 0.5273, Train Acc: 99.19%
#    Val Loss: 0.5952, Val Acc: 96.48%
#     New best model saved! Val Acc: 96.48%
# ----------------------------------------------------------------------
# Epoch 16/40 [Train]:   0%|          | 0/120 [00:00<?, ?it/s]
# Epoch 16/40 [Val]:   0%|          | 0/26 [00:00<?, ?it/s]
#  Epoch 16/40 Results:
#    Train Loss: 0.5203, Train Acc: 99.48%
#    Val Loss: 0.6198, Val Acc: 95.15%
# ----------------------------------------------------------------------
#  Early stopping triggered after epoch 16
#
#  Best validation accuracy achieved: 96.48%
#
#  Plotting training history...
# ============================================================
#  Evaluating on test set...
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
#  Final Test Accuracy: 95.40%
#
#  Classification Report:
# ================================================================================
#               precision    recall  f1-score   support
#
#     01_TUMOR     0.9677    0.9677    0.9677        93
#    02_STROMA     0.9694    0.9223    0.9453       103
#   03_COMPLEX     0.8200    0.8913    0.8542        92
#    04_LYMPHO     0.9200    0.9787    0.9485        94
#    05_DEBRIS     0.9524    0.9195    0.9357        87
#    06_MUCOSA     1.0000    0.9588    0.9789        97
#   07_ADIPOSE     1.0000    0.9818    0.9908       110
#     08_EMPTY     0.9872    0.9747    0.9809        79
#      UNKNOWN     0.9861    1.0000    0.9930        71
#
#     accuracy                         0.9540       826
#    macro avg     0.9559    0.9550    0.9550       826
# weighted avg     0.9560    0.9540    0.9545       826
#
#
#  Cohen's Kappa Score: 0.9482
#     Excellent agreement
#
#  Generating visualizations...
# ============================================================
#  FINAL RESULTS SUMMARY
# ============================================================
#  Test Accuracy:     95.40%
#  Mean AUC Score:    0.998
#  Cohen's Kappa:     0.9482
#  Best Val Accuracy: 96.48%
#
#  Models saved successfully!
#    - best_colorectal_model.pth (best weights)
#    - final_colorectal_model.pth (with metadata)

# %%
import zipfile

file_paths = [
    '/kaggle/working/best_colorectal_model.pth',
    '/kaggle/working/final_colorectal_model.pth'
]

zip_file_path = '/kaggle/working/modelsDenseNet121.zip'

with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    for file in file_paths:
        zipf.write(file, arcname=file.split('/')[-1])

print("Created zip file:", zip_file_path)
# Out:
# Created zip file: /kaggle/working/modelsDenseNet121.zip

# %%
from IPython.display import FileLink
FileLink(r'modelsDenseNet121.zip')
# Out:
# /kaggle/working/modelsDenseNet121.zip
